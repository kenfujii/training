# %%
import pandas as pd
import sqlite3

# %% [markdown]
# # Movie Ratings

# %% [markdown]
# You've started a new movie-rating website, and you've been collecting data on reviewers' ratings of various movies. There's not much data yet, but you can still try out some interesting queries. Here's the schema:
#
# Movie ( mID, title, year, director )
# English: There is a movie with ID number mID, a title, a release year, and a director.
#
# Reviewer ( rID, name )
# English: The reviewer with ID number rID has a certain name.
#
# Rating ( rID, mID, stars, ratingDate )
# English: The reviewer rID gave the movie mID a number of stars rating (1-5) on a certain ratingDate.

# %%
con = sqlite3.connect("movie-ratings.sqlite")
df = pd.read_sql("SELECT * from Rating limit 3", con)
df
# Out:
#    rID  mID  stars  ratingDate
# 0  201  101      2  2011-01-22
# 1  201  101      4  2011-01-27
# 2  202  106      4        None

# %% [markdown]
# Find the titles of all movies directed by Steven Spielberg.

# %%
ss = pd.read_sql("SELECT title from Movie WHERE director = 'Steven Spielberg'", con)
ss
# Out:
#                      title
# 0                     E.T.
# 1  Raiders of the Lost Ark

# %% [markdown]
# Find all years that have a movie that received a rating of 4 or 5, and sort them in increasing order.

# %%
ds = pd.read_sql("SELECT year from Movie WHERE EXISTS (SELECT * FROM Rating WHERE stars>= 4) ORDER By year", con)
ds
# Out:
#    year
# 0  1937
# 1  1939
# 2  1965
# 3  1977
# 4  1981
# 5  1982
# 6  1997
# 7  2009

# %% [markdown]
# Find the titles of all movies that have no ratings.

# %% [raw]
# ds = pd.read_sql("SELECT title FROM Movie WHERE EXISTS (SELECT * FROM Rating WHERE stars is null)", con)
# ds

# %% [markdown]
# Some reviewers didn't provide a date with their rating. Find the names of all reviewers who have ratings with a NULL value for the date.

# %%
ds = pd.read_sql("SELECT name FROM Reviewer WHERE EXISTS (SELECT * FROM Rating WHERE ratingDate is null)", con)
ds
# Out:
#                name
# 0    Sarah Martinez
# 1      Daniel Lewis
# 2   Brittany Harris
# 3     Mike Anderson
# 4     Chris Jackson
# 5  Elizabeth Thomas
# 6     James Cameron
# 7      Ashley White

# %% [markdown]
# Write a query to return the ratings data in a more readable format: reviewer name, movie title, stars, and ratingDate. Also, sort the data, first by reviewer name, then by movie title, and lastly by number of stars.

# %%
ds = pd.read_sql("SELECT R1.name, M1.title, Ra1.stars, Ra1.ratingDate FROM Movie M1, Reviewer R1, Rating Ra1 order by R1.name, M1.title, Ra1.stars", con)
ds
# Out:
#                name               title  stars  ratingDate
# 0      Ashley White              Avatar      2  2011-01-22
# 1      Ashley White              Avatar      2  2011-01-20
# 2      Ashley White              Avatar      2  2011-01-30
# 3      Ashley White              Avatar      2  2011-01-22
# 4      Ashley White              Avatar      3  2011-01-09
# 5      Ashley White              Avatar      3  2011-01-27
# 6      Ashley White              Avatar      3  2011-01-15
# 7      Ashley White              Avatar      3  2011-01-02
# 8      Ashley White              Avatar      4  2011-01-27
# 9      Ashley White              Avatar      4        None
# 10     Ashley White              Avatar      4  2011-01-12
# 11     Ashley White              Avatar      4        None
# 12     Ashley White              Avatar      5  2011-01-19
# 13     Ashley White              Avatar      5  2011-01-20
# 14     Ashley White                E.T.      2  2011-01-22
# ...

# %% [markdown]
# For all cases where the same reviewer rated the same movie twice and gave it a higher rating the second time, return the reviewer's name and the title of the movie.

# %%
ds = pd.read_sql("SELECT name, title FROM (SELECT name, count(Rating.rID) as cnt, Rating.mID, title, stars, ratingDate FROM Rating join Reviewer on Rating.rid = Reviewer.rid join Movie on Movie.mID = Rating.mID group by Rating.rID, Rating.mID) as T WHERE t.cnt > 1 limit 1",con)
ds
# Out:
#              name               title
# 0  Sarah Martinez  Gone with the Wind

# %% [markdown]
# For each movie that has at least one rating, find the highest number of stars that movie received. Return the movie title and number of stars. Sort by movie title.

# %%
ds = pd.read_sql("SELECT title, MAX(stars) from Rating join Movie on Movie.mID=Rating.mID group by Movie.mID order by title", con)
ds
# Out:
#                      title  MAX(stars)
# 0                   Avatar           5
# 1                     E.T.           3
# 2       Gone with the Wind           4
# 3  Raiders of the Lost Ark           4
# 4               Snow White           5
# 5       The Sound of Music           3

# %% [markdown]
# For each movie, return the title and the 'rating spread', that is, the difference between highest and lowest ratings given to that movie. Sort by rating spread from highest to lowest, then by movie title.

# %%
ds = pd.read_sql("SELECT title, (Max(stars)-Min(stars)) as ms from Rating join Movie on Movie.mID=Rating.mID group by Movie.mID order by ms, title", con)
ds
# Out:
#                      title  ms
# 0                     E.T.   1
# 1               Snow White   1
# 2       The Sound of Music   1
# 3                   Avatar   2
# 4       Gone with the Wind   2
# 5  Raiders of the Lost Ark   2

# %% [markdown]
# Find the difference between the average rating of movies released before 1980 and the average rating of movies released after 1980. (Make sure to calculate the average rating for each movie, then the average of those averages for movies before 1980 and movies after. Don't just calculate the overall average rating before and after 1980.)

# %%
ds = pd.read_sql("SELECT avg(stars) FROM Rating join Movie on Movie.mID=Rating.mID group by Movie.year", con)
ds
# Out:
#    avg(stars)
# 0    4.500000
# 1    3.000000
# 2    2.500000
# 3    3.333333
# 4    2.500000
# 5    4.000000

# %% [markdown]
# # The Social Network

# %% [markdown]
# Students at your hometown high school have decided to organize their social network using databases. So far, they have collected information about sixteen students in four grades, 9-12. Here's the schema:
#
# Highschooler ( ID, name, grade )
# English: There is a high school student with unique ID and a given first name in a certain grade.
#
# Friend ( ID1, ID2 )
# English: The student with ID1 is friends with the student with ID2. Friendship is mutual, so if (123, 456) is in the Friend table, so is (456, 123).
#
# Likes ( ID1, ID2 )
# English: The student with ID1 likes the student with ID2. Liking someone is not necessarily mutual, so if (123, 456) is in the Likes table, there is no guarantee that (456, 123) is also present.

# %%
con = sqlite3.connect("social.sqlite")
df = pd.read_sql("SELECT * from Highschooler limit 3", con)
df
# Out:
#      ID     name  grade
# 0  1510   Jordan      9
# 1  1689  Gabriel      9
# 2  1381  Tiffany      9

# %% [markdown]
# Find the names of all students who are friends with someone named Gabriel.

# %% [markdown]
# For every student who likes someone 2 or more grades younger than themselves, return that student's name and grade, and the name and grade of the student they like.

# %% [markdown]
# For every pair of students who both like each other, return the name and grade of both students. Include each pair only once, with the two names in alphabetical order.

# %% [markdown]
# Find all students who do not appear in the Likes table (as a student who likes or is liked) and return their names and grades. Sort by grade, then by name within each grade.

# %% [markdown]
# For every situation where student A likes student B, but we have no information about whom B likes (that is, B does not appear as an ID1 in the Likes table), return A and B's names and grades.

# %% [markdown]
# Find names and grades of students who only have friends in the same grade. Return the result sorted by grade, then by name within each grade.

# %% [markdown]
# For each student A who likes a student B where the two are not friends, find if they have a friend C in common (who can introduce them!). For all such trios, return the name and grade of A, B, and C.

# %% [markdown]
# Find the difference between the number of students in the school and the number of different first names.

# %% [markdown]
# Find the name and grade of all students who are liked by more than one other student.

# %% [markdown]
# ## Modification

# %% [markdown]
# Add the reviewer Roger Ebert to your database, with an rID of 209.

# %% [markdown]
# Insert 5-star ratings by James Cameron for all movies in the database. Leave the review date as NULL.

# %% [markdown]
# For all movies that have an average rating of 4 stars or higher, add 25 to the release year. (Update the existing tuples; don't insert new tuples.)

# %% [markdown]
# Remove all ratings where the movie's year is before 1970 or after 2000, and the rating is fewer than 4 stars.

# %% [markdown]
# It's time for the seniors to graduate. Remove all 12th graders from Highschooler.

# %% [markdown]
# If two students A and B are friends, and A likes B but not vice-versa, remove the Likes tuple.

# %% [markdown]
# For all cases where A is friends with B, and B is friends with C, add a new friendship for the pair A and C. Do not add duplicate friendships, friendships that already exist, or friendships with oneself. (This one is a bit challenging; congratulations if you get it right.)
