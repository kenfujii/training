# %%
import numpy as np
from numpy import nan as NA
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from pylab import *
import random
from scipy.stats import norm

#mpl.style.available
#mpl.style.use('ggplot') 
# %matplotlib inline

# %% [markdown]
# Import as a dataframe run10.txt

# %%
df=pd.read_table("/home/vagrant/notebooks/training/Stats/run10.txt")
df
# Out:
#        place    time    pace  age gender             location state  divPlace  \
# 0       4494   92.25   9.225   38      M  Chesapeake Beach MD    MD       690
# 1       6298  106.35  10.635   33      M        Washington DC    DC      1322
# 2       2502   89.33   8.933   55      F            McLean VA    VA        37
# 3       8176  113.50  11.350   24      F        Alexandria VA    VA       878
# 4       3413   86.52   8.652   54      M     San Francisco CA    CA       213
# 5       8008  112.30  11.230   42      F       Chevy Chase MD    MD       785
# 6       8791  118.45  11.845   36      F           Fairfax VA    VA      1215
# 7       3987   95.17   9.517   25      F         Arlington VA    VA      1230
# 8       3451   93.25   9.325   25      F      Philadelphia PA    PA      1074
# 9       1046   72.37   7.237   43      M          Pasadena MD    MD       111
# 10      3484   86.90   8.690   55      M      Falls Church VA    VA       138
# 11      2987   84.47   8.447   30      M           Potomac MD    MD       659
# 12      4427   96.65   9.665   39      F            Walnut CA    CA       587
# 13      6496  108.93  10.893   40      M       Springfield VA    VA       846
# 14      5827  101.58  10.158   30      F        Washington DC    DC      1297
# 15      1224   82.78   8.278   24      F         Arlington VA    VA       164
# 16      4942   98.32   9.832   45      F           Potomac MD    MD       255
# 17      9579  134.18  13.418   33      F          Sterling VA    VA      2189
# 18      6425  107.98  10.798   41      M         Arlington VA    VA       831
# 19      5951  102.08  10.208   36      F        Alexandria VA    VA       809
# 20      8609  116.78  11.678   38      F            Edison NJ    NJ      1189
# 21      3586   87.42   8.742   45      M       Branchville NJ    NJ       314
# 22      3823   94.58   9.458   35      F        New Market MD    MD       517
# 23      2123   79.25   7.925   37      M            McLean VA    VA       307
# 24      4517   92.37   9.237   23      M        Washington DC    DC       229
# 25      6525  109.28  10.928   51      M         Annandale VA    VA       444
# 26       227   62.47   6.247   30      M           Herndon VA    VA        66
# 27      6462  108.45  10.845   46      M         Arlington VA    VA       577
# 28      7503  109.05  10.905   27      F         Arlington VA    VA      2269
# 29      5751  100.62  10.062   23      M         Baltimore MD    MD       297
# ...      ...     ...     ...  ...    ...                  ...   ...       ...
# 16894   5730  100.43  10.043   25      M        Washington DC    DC      1210
# 16895   1214   73.67   7.367   30      M            Reston VA    VA       297
# 16896   5517  100.45  10.045   24      F      Millersville MD    MD       660
# 16897    359   64.88   6.488   31      M          Columbia MD    MD       100
# 16898   1876   77.95   7.795   30      M      Philadelphia PA    PA       423
# 16899    984   71.88   7.188   32      M        Washington DC    DC       252
# 16900   2717   90.30   9.030   32      F       Gainesville VA    VA       602
# 16901   4103   90.08   9.008   25      M        Washington DC    DC       902
# 16902   3863   88.75   8.875   43      M           Potomac MD    MD       491
# 16903   3200   92.28   9.228   22      F       Chevy Chase MD    MD       424
# 16904   7565  109.40  10.940   25      F         Arlington VA    VA      2283
# 16905   2151   87.87   8.787   32      F          Brooklyn NY    NY       477
# 16906   6285  103.50  10.350   25      F         Arlington VA    VA      1917
# 16907    678   68.95   6.895   33      M        Washington DC    DC       185
# 16908   5064   98.75   9.875   38      F         Baltimore MD    MD       674
# 16909   5971  102.17  10.217   36      F    Mechanicsville VA    VA       810
# 16910    988   71.90   7.190   29      M          Bethesda MD    MD       235
# 16911   1773   86.18   8.618   36      F       Chevy Chase MD    MD       227
# 16912   2069   79.02   7.902   38      M         Baltimore MD    MD       300
# 16913   2479   81.47   8.147   29      M        Alexandria VA    VA       589
# 16914   7031  123.42  12.342   32      M         Montclair VA    VA      1457
# 16915   3539   87.13   8.713   43      M             Wayne PA    PA       455
# 16916   1337   83.62   8.362   40      F     Hollidaysburg PA    PA       128
# 16917   5040   98.65   9.865   23      F         Arlington VA    VA       612
# 16918   4322   91.30   9.130   28      M        Washington DC    DC       938
# 16919    329   64.45   6.445   32      M         Arlington VA    VA        92
# 16920   4475   96.83   9.683   36      F          Carlisle PA    PA       595
# 16921   6243  103.30  10.330   30      F        Washington DC    DC      1398
# 16922   9133  122.87  12.287   37      F            Reston VA    VA      1269
# 16923   3462   93.30   9.330   27      F        Washington DC    DC      1079
#
#        divTot
# 0        1093
# 1        1490
# 2         236
# 3         974
# 4         483
# 5         974
# 6        1367
# 7        2782
# 8        2782
# 9         931
# 10        375
# 11       1490
# 12       1367
# 13        931
# 14       2228
# 15        974
# 16        554
# 17       2228
# 18        931
# 19       1367
# 20       1367
# 21        648
# 22       1367
# 23       1093
# 24        347
# 25        483
# 26       1490
# 27        648
# 28       2782
# 29        347
# ...       ...
# 16894    1457
# 16895    1490
# 16896     974
# 16897    1490
# 16898    1490
# 16899    1490
# 16900    2228
# 16901    1457
# 16902     931
# 16903     974
# 16904    2782
# 16905    2228
# 16906    2782
# 16907    1490
# 16908    1367
# 16909    1367
# 16910    1457
# 16911    1367
# 16912    1093
# 16913    1457
# 16914    1490
# 16915     931
# 16916     974
# 16917     974
# 16918    1457
# 16919    1490
# 16920    1367
# 16921    2228
# 16922    1367
# 16923    2782
#
# [16924 rows x 9 columns]

# %% [markdown]
# Explore the time variable

# %%
time = df['time']
time
# Out:
# 0      92.25
# 1     106.35
# 2      89.33
# 3     113.50
# 4      86.52
# 5     112.30
# 6     118.45
# 7      95.17
# 8      93.25
# 9      72.37
# 10     86.90
# 11     84.47
# 12     96.65
# 13    108.93
# 14    101.58
# ...
# 16909    102.17
# 16910     71.90
# 16911     86.18
# 16912     79.02
# 16913     81.47
# 16914    123.42
# 16915     87.13
# 16916     83.62
# 16917     98.65
# 16918     91.30
# 16919     64.45
# 16920     96.83
# 16921    103.30
# 16922    122.87
# 16923     93.30
# Name: time, Length: 16924, dtype: float64

# %% [markdown]
#    Calculate the mean and standard deviation of the time of the runners. Name them population_mean and population_sd respectively. Hint: Use .mean() and .std()

# %%
population_mean = mean(time)
population_sd = std(time)

# %% [markdown]
# Produce a histogram and a fitted density of the time variable. *Beware* of the y-axis range.

# %%
time.hist(normed=True)
time.plot(kind='kde')

# %% [markdown]
# Get a sample the time of 100 individuals from the data. Use random.sample(data,size of sample)

# %%
ransamp_time = random.sample(df['time'],100)
ransamp_time
# Out:
# [89.329999999999998,
#  87.219999999999999,
#  102.83,
#  95.549999999999997,
#  99.030000000000001,
#  95.620000000000005,
#  89.5,
#  103.78,
#  96.930000000000007,
#  80.969999999999999,
#  101.09999999999999,
#  93.0,
#  80.599999999999994,
#  102.90000000000001,
#  137.44999999999999,
#  94.280000000000001,
#  72.019999999999996,
#  74.569999999999993,
#  96.75,
#  104.52,
#  68.469999999999999,
#  104.5,
#  76.579999999999998,
#  98.480000000000004,
#  95.879999999999995,
#  116.72,
#  84.469999999999999,
#  84.629999999999995,
#  95.849999999999994,
#  90.769999999999996,
#  63.280000000000001,
#  88.599999999999994,
#  101.48,
#  81.819999999999993,
#  82.829999999999998,
#  77.049999999999997,
#  99.829999999999998,
#  85.650000000000006,
#  97.019999999999996,
#  92.280000000000001,
#  116.65000000000001,
#  92.5,
#  124.31999999999999,
#  94.75,
#  83.370000000000005,
#  78.879999999999995,
#  90.5,
#  115.53,
#  112.5,
#  81.629999999999995,
#  85.25,
#  94.120000000000005,
#  113.25,
#  84.120000000000005,
#  114.18000000000001,
#  94.180000000000007,
#  89.670000000000002,
#  76.829999999999998,
#  98.349999999999994,
#  123.22,
#  119.55,
#  80.219999999999999,
#  119.03,
#  98.870000000000005,
#  92.049999999999997,
#  103.40000000000001,
#  91.849999999999994,
#  129.59999999999999,
#  98.349999999999994,
#  99.319999999999993,
#  105.63,
#  90.370000000000005,
#  103.43000000000001,
#  96.319999999999993,
#  96.379999999999995,
#  85.719999999999999,
#  96.75,
#  128.62,
#  104.22,
#  105.62,
#  107.53,
#  77.25,
#  113.97,
#  92.120000000000005,
#  65.530000000000001,
#  110.90000000000001,
#  88.549999999999997,
#  102.23,
#  77.980000000000004,
#  101.37,
#  94.819999999999993,
#  86.120000000000005,
#  95.829999999999998,
#  87.0,
#  87.450000000000003,
#  119.38,
#  87.680000000000007,
#  67.829999999999998,
#  93.269999999999996,
#  99.420000000000002]

# %% [markdown]
# Produce a histogram and a fitted density of the time variable for the sample.

# %%
hist(ransamp_time,normed=True)
series = pd.Series(ransamp_time)
series.plot(kind='kde')

# %% [markdown]
# Calculate the mean and standard deviation of the sample

# %%
hist(ransamp_time,normed=True)
mean_ransam = sum(time)/len(time)
sd_ransam = std(time)

# %% [markdown]
# Evaluate the lower bound of a 95% interval. Name it lower

# %%
lower = mean_ransam - 2*sd_ransam
lower
# Out:
# 62.665819955678842

# %% [markdown]
# Evaluate the upper bound of a 95% interval. Name it upper

# %%
upper = mean_ransam + 2*sd_ransam
upper
# Out:
# 126.37256458698246

# %% [markdown]
# Plot the confidence interval and the mean of the sample.

# %%
# To plot a line between points (x1,y1) and (x2,y2) in Python use plt.plot((x1,x2),(y1,y2))
# To plot a point (x,y) use plt.plot(x,y,'.')

series = pd.Series(ransamp_time)
hist(series,normed=True)
plt.plot((lower,upper),(0.015,0.015))
plt.plot(population_mean,0.015,'.', color='red')

# %% [markdown]
# Assign an empty list to the variable average, standard_error, lower, upper.

# %%
average = []
standard_error=[]
lower = []
upper = []

# %% [markdown]
# Use a for loop to produce 4  samples of size 100,1000,10000,15000. For every sample calculate the average, standard_error,lower, upper and append the lists.

# %%
# Creat a for loop for i in  [100,1000,10000,15000] sample sizes
for i in [100,1000,10000,15000]:
    # Sample i observations from the time variable
    time = random.sample(df['time'], i)
    # Evaluate the average of the sample and append it to the average list.
    avg_time = sum(time)/len(time)
    average.append(avg_time)
    # Evaluate the SE of the sample and append it to the sample_SE list.
    sd_error_time = std(time)
    standard_error.append(sd_error_time)
    # Evaluate the lower bound of a 95% confidence interval and append it to the lower list.
    lower.append(avg_time - 2*sd_error_time)
    # Evaluate the upper bound of a 95% confidence interval and append it to the upper list.
    upper.append(avg_time + 2*sd_error_time)

# %% [markdown]
# Produce a plot with the 4 different confidence intervals, their respective averages and a vertical line representing the population mean.

# %%
# Use plt.figure() to initialize a plot. Play around with the figure size

# Create a for loop for the 4 different samples
for i in [100,1000,10000,15000]:
    # Plot the confidence interval of the ith sample
    hist(series,normed=True)
    plt.plot((lower[i],upper[i]),(0.015,0.015))
    # Plot a point for the average of the ith sample
    plt.plot(mean[i],0.015,'.',color='red')
    # Exit the for loop and plot a vertical line of the population mean


plt.title("95% confidence intervals as the sample size increases")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-36-351566634fe6> in <module>()
#       5     # Plot the confidence interval of the ith sample
#       6     hist(series,normed=True)
# ----> 7     plt.plot((lower[i],upper[i]),(0.015,0.015))
#       8     # Plot a point for the average of the ith sample
#       9     plt.plot(mean[i],0.015,'.',color='red')
#
# IndexError: list index out of range

# %% [markdown]
# Comment on the behaviour of the confidence intervals as the sample size increases. Is this expected?

# %% [markdown]
# Assign an empty list to variable average,standard_error,lower, upper

# %%
average = []
standard_error = []
lower = []
upper = []

# %% [markdown]
# Use a for loop to produce 50  samples of size 100. For every sample append the lists average, standard_error,lower, upper with the respective values.

# %%
# Creat a for loop for 50 iterations
for i in range(50):
    # Sample 100 observations from the time variable
    
    # Evaluate the average of the sample and append it to the average list.
    
    # Evaluate the SE of the sample and append it to the sample_SE list.
    
    # Evaluate the lower bound of a 95% confidence interval and append it to the lower list.
    
    # Evaluate the upper bound of a 95% confidence interval and append it to the upper list.

# %% [markdown]
# Produce a histogram of the average.

# %% [markdown]
# Produce a plot with the 50 different confidence intervals, their respective averages and a vertical line representing the population mean.

# %%
# Use plt.figure() to initialize a plot. Play around with the figure size

# Create a for loop of 50 iterations

# Plot the confidence interval of the ith sample

# Plot a point for the average of the ith sample


# Exit the for loop and plot a vertical line of the population mean

plt.title("95% confidence intervals")

# %% [markdown]
# Comment the on the graph that is produced.
