# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from pylab import *
import scipy.stats as stats
import pylab



#mpl.style.available
#mpl.style.use('ggplot') 
# %matplotlib inline

# %% [markdown]
# ##Description
# 9 variables for all 16,924 10 mile participants in the 2012 Cherry Blossom Run.
#
# ##Format
#  The run10 (2012 data) summarizes 16,924 observations on 9 variables.
#
# place: Finishing position. Separate positions are provided for each gender.
#
# time: The total run time. For run10, this is equivalent to netTime. netTime The run time from the start line to the finish line.
#
# pace: The listed pace for each runner.
#
# age: Age.
#
# gender: Gender.
#
# location: Hometown city.
#
# state: Hometown state.
#
# divPlace: Division place, also broken up by gender. (Division is running devision by age.)
#
# divTot: Total number of people in the division (again, also split by gender).

# %% [markdown]
# Import as a dataframe run10.txt

# %%
df=pd.read_table("/home/vagrant/notebooks/training/Stats/run10.txt")
df
# Out:
#        place    time    pace  age gender             location state  divPlace  \
# 0       4494   92.25   9.225   38      M  Chesapeake Beach MD    MD       690
# 1       6298  106.35  10.635   33      M        Washington DC    DC      1322
# 2       2502   89.33   8.933   55      F            McLean VA    VA        37
# 3       8176  113.50  11.350   24      F        Alexandria VA    VA       878
# 4       3413   86.52   8.652   54      M     San Francisco CA    CA       213
# 5       8008  112.30  11.230   42      F       Chevy Chase MD    MD       785
# 6       8791  118.45  11.845   36      F           Fairfax VA    VA      1215
# 7       3987   95.17   9.517   25      F         Arlington VA    VA      1230
# 8       3451   93.25   9.325   25      F      Philadelphia PA    PA      1074
# 9       1046   72.37   7.237   43      M          Pasadena MD    MD       111
# 10      3484   86.90   8.690   55      M      Falls Church VA    VA       138
# 11      2987   84.47   8.447   30      M           Potomac MD    MD       659
# 12      4427   96.65   9.665   39      F            Walnut CA    CA       587
# 13      6496  108.93  10.893   40      M       Springfield VA    VA       846
# 14      5827  101.58  10.158   30      F        Washington DC    DC      1297
# 15      1224   82.78   8.278   24      F         Arlington VA    VA       164
# 16      4942   98.32   9.832   45      F           Potomac MD    MD       255
# 17      9579  134.18  13.418   33      F          Sterling VA    VA      2189
# 18      6425  107.98  10.798   41      M         Arlington VA    VA       831
# 19      5951  102.08  10.208   36      F        Alexandria VA    VA       809
# 20      8609  116.78  11.678   38      F            Edison NJ    NJ      1189
# 21      3586   87.42   8.742   45      M       Branchville NJ    NJ       314
# 22      3823   94.58   9.458   35      F        New Market MD    MD       517
# 23      2123   79.25   7.925   37      M            McLean VA    VA       307
# 24      4517   92.37   9.237   23      M        Washington DC    DC       229
# 25      6525  109.28  10.928   51      M         Annandale VA    VA       444
# 26       227   62.47   6.247   30      M           Herndon VA    VA        66
# 27      6462  108.45  10.845   46      M         Arlington VA    VA       577
# 28      7503  109.05  10.905   27      F         Arlington VA    VA      2269
# 29      5751  100.62  10.062   23      M         Baltimore MD    MD       297
# ...      ...     ...     ...  ...    ...                  ...   ...       ...
# 16894   5730  100.43  10.043   25      M        Washington DC    DC      1210
# 16895   1214   73.67   7.367   30      M            Reston VA    VA       297
# 16896   5517  100.45  10.045   24      F      Millersville MD    MD       660
# 16897    359   64.88   6.488   31      M          Columbia MD    MD       100
# 16898   1876   77.95   7.795   30      M      Philadelphia PA    PA       423
# 16899    984   71.88   7.188   32      M        Washington DC    DC       252
# 16900   2717   90.30   9.030   32      F       Gainesville VA    VA       602
# 16901   4103   90.08   9.008   25      M        Washington DC    DC       902
# 16902   3863   88.75   8.875   43      M           Potomac MD    MD       491
# 16903   3200   92.28   9.228   22      F       Chevy Chase MD    MD       424
# 16904   7565  109.40  10.940   25      F         Arlington VA    VA      2283
# 16905   2151   87.87   8.787   32      F          Brooklyn NY    NY       477
# 16906   6285  103.50  10.350   25      F         Arlington VA    VA      1917
# 16907    678   68.95   6.895   33      M        Washington DC    DC       185
# 16908   5064   98.75   9.875   38      F         Baltimore MD    MD       674
# 16909   5971  102.17  10.217   36      F    Mechanicsville VA    VA       810
# 16910    988   71.90   7.190   29      M          Bethesda MD    MD       235
# 16911   1773   86.18   8.618   36      F       Chevy Chase MD    MD       227
# 16912   2069   79.02   7.902   38      M         Baltimore MD    MD       300
# 16913   2479   81.47   8.147   29      M        Alexandria VA    VA       589
# 16914   7031  123.42  12.342   32      M         Montclair VA    VA      1457
# 16915   3539   87.13   8.713   43      M             Wayne PA    PA       455
# 16916   1337   83.62   8.362   40      F     Hollidaysburg PA    PA       128
# 16917   5040   98.65   9.865   23      F         Arlington VA    VA       612
# 16918   4322   91.30   9.130   28      M        Washington DC    DC       938
# 16919    329   64.45   6.445   32      M         Arlington VA    VA        92
# 16920   4475   96.83   9.683   36      F          Carlisle PA    PA       595
# 16921   6243  103.30  10.330   30      F        Washington DC    DC      1398
# 16922   9133  122.87  12.287   37      F            Reston VA    VA      1269
# 16923   3462   93.30   9.330   27      F        Washington DC    DC      1079
#
#        divTot
# 0        1093
# 1        1490
# 2         236
# 3         974
# 4         483
# 5         974
# 6        1367
# 7        2782
# 8        2782
# 9         931
# 10        375
# 11       1490
# 12       1367
# 13        931
# 14       2228
# 15        974
# 16        554
# 17       2228
# 18        931
# 19       1367
# 20       1367
# 21        648
# 22       1367
# 23       1093
# 24        347
# 25        483
# 26       1490
# 27        648
# 28       2782
# 29        347
# ...       ...
# 16894    1457
# 16895    1490
# 16896     974
# 16897    1490
# 16898    1490
# 16899    1490
# 16900    2228
# 16901    1457
# 16902     931
# 16903     974
# 16904    2782
# 16905    2228
# 16906    2782
# 16907    1490
# 16908    1367
# 16909    1367
# 16910    1457
# 16911    1367
# 16912    1093
# 16913    1457
# 16914    1490
# 16915     931
# 16916     974
# 16917     974
# 16918    1457
# 16919    1490
# 16920    1367
# 16921    2228
# 16922    1367
# 16923    2782
#
# [16924 rows x 9 columns]

# %% [markdown]
# Explore the first lines of the data

# %%
df.head()
# Out:
#    place    time    pace  age gender             location state  divPlace  \
# 0   4494   92.25   9.225   38      M  Chesapeake Beach MD    MD       690
# 1   6298  106.35  10.635   33      M        Washington DC    DC      1322
# 2   2502   89.33   8.933   55      F            McLean VA    VA        37
# 3   8176  113.50  11.350   24      F        Alexandria VA    VA       878
# 4   3413   86.52   8.652   54      M     San Francisco CA    CA       213
#
#    divTot
# 0    1093
# 1    1490
# 2     236
# 3     974
# 4     483

# %% [markdown]
# Get a summary of the data

# %%
df.dtypes
# Out:
# place         int64
# time        float64
# pace        float64
# age         float64
# gender       object
# location     object
# state        object
# divPlace    float64
# divTot      float64
# dtype: object

# %% [markdown]
# Use pd.scatter_matrix(dataframe) on the dataframe to get an overview of the relationships between the variables.
# If you need to enlarge the plot add the argument figsize=(15,15) in pd.scatter_matrix.

# %%
pd.scatter_matrix(df, figsize=(15,15))
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x7fd683c97cd0>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd68439a110>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd6842fef10>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd684281cd0>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd6841ea9d0>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd68416d890>],
#        [<matplotlib.axes.AxesSubplot object at 0x7fd684128910>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd684067410>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd683feb1d0>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd683fd34d0>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd683f63390>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd683eb0e90>],
#        [<matplotlib.axes.AxesSubplot object at 0x7fd683e4f190>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd683e09310>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd683d39b50>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd683cbe910>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd683be4990>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd683b73910>],
#        [<matplotlib.axes.AxesSubplot object at 0x7fd683b4e390>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd683a61650>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd683a957d0>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd6839d9050>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd683952dd0>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd6838b8e50>],
#        [<matplotlib.axes.AxesSubplot object at 0x7fd683848dd0>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd683c218d0>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd683798890>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd68371d650>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd683681c50>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd6836132d0>],
#        [<matplotlib.axes.AxesSubplot object at 0x7fd6835779d0>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd6834fbc90>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd68359ccd0>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd6833f4410>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd68337a1d0>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd6832e0a50>]], dtype=object)

# %% [markdown]
# Study the relationship between the variables.

# %% [markdown]
# Use pd.scatter_matrix('Variable') to get an overview of the relationships between time,pace and age.

# %%
variablesdf = df.loc[:,['time','pace','age']]
pd.scatter_matrix(variablesdf)
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x7fd67a6fdb90>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd67a785dd0>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd67a885b50>],
#        [<matplotlib.axes.AxesSubplot object at 0x7fd67a042490>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd67aa4ad10>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd67ab3a4d0>],
#        [<matplotlib.axes.AxesSubplot object at 0x7fd67acbc110>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd67acc0b10>,
#         <matplotlib.axes.AxesSubplot object at 0x7fd67ae64c50>]], dtype=object)

# %% [markdown]
# Study the graph and comment on the relations of the variables.

# %% [markdown]
# # Comparison of different groups.

# %% [markdown]
# Group the database by gender. In oder to group data use .groupby('Variable')

# %%
ds=df.groupby('gender')

# %% [markdown]
# Get a summary of the grouped data.

# %%
ds.describe()
# Out:
#                       age     divPlace       divTot         pace        place  \
# gender
# F      count  9732.000000  9732.000000  9732.000000  9732.000000  9732.000000
#        mean     33.877620   874.246301  1747.492602     9.901558  4866.500000
#        std       9.274390   715.656644   879.194231     1.468149  2809.530744
#        min      12.000000     1.000000     1.000000     5.403000     1.000000
#        25%      27.000000   283.000000   974.000000     8.908000  2433.750000
#        50%      32.000000   692.000000  2228.000000     9.803000  4866.500000
#        75%      39.000000  1315.000000  2782.000000    10.790000  7299.250000
#        max      75.000000  2782.000000  2782.000000    17.097000  9732.000000
# M      count  7191.000000  7191.000000  7191.000000  7192.000000  7192.000000
#        mean     37.745237   512.810736  1024.621471     8.843481  3596.500000
#        std      10.866987   393.453447   449.353202     1.552157  2076.295901
#        min       9.000000     1.000000     2.000000     4.525000     1.000000
#        25%      29.000000   181.000000   648.000000     7.756000  1798.750000
#        50%      35.000000   418.000000  1093.000000     8.747000  3596.500000
#        75%      45.000000   794.000000  1457.000000     9.778000  5394.250000
#        max      89.000000  1490.000000  1490.000000    15.098000  7192.000000
#
#                      time
# gender
# F      count  9732.000000
#        mean     99.015584
#        std      14.681487
#        min      54.030000
#        25%      89.080000
#        50%      98.030000
#        75%     107.900000
#        max     170.970000
# M      count  7192.000000
#        mean     88.434810
#        std      15.521568
#        min      45.250000
#        25%      77.560000
#        50%      87.470000
#        75%      97.780000
#        max     150.980000

# %% [markdown]
# Comment on the graph that is produced by following code and give an appropriate name in plt.legend()

# %%
for color, label in zip('bg', ['F','M']):
    subset = df[df.gender == label]
    plt.scatter(subset.time, subset.age, c=color, label=str(label))
plt.legend()

# %% [markdown]
# Produce a histogramm of time variable for the grouped data

# %%
subset1 = df[df.gender=="F"]
subset2 = df[df.gender=="M"]
subset1['time'].hist()
subset2['time'].hist()

# %% [markdown]
# Produce a histogramm for the grouped data and overimpose the fitted densities.

# %%
subset1['time'].plot(kind='kde')
subset2['time'].plot(kind='kde')
subset1['time'].hist(normed=True)
subset2['time'].hist(normed=True)

# %% [markdown]
# Check graphically, if the running times of men, follow a normal distribution.

# %%
stats.probplot(subset2['time'],plot=pylab)
# Out:
# ((array([-3.72833929, -3.49851474, -3.37211613, ...,  3.37211613,
#           3.49851474,  3.72833929]),
#   array([  45.25,   46.47,   47.55, ...,  147.5 ,  148.97,  150.98])),
#  (15.438580358551963, 88.434809510567305, 0.99424366075831749))
